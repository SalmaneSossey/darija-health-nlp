# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
print("Project root:", PROJECT_ROOT)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %%
from backend.app.symptom_extractor import extract_symptoms
from backend.app.urgency_rules import classify_urgency

examples = [
    "3ndi wje3 f sedri w di9 f nefs",
    "عندي ألم فالصدر وضيق فالتنفس",
    "j’ai mal au ventre depuis 3 jours",
    "waldi 3ndo skhana w k7a",
]
for text in examples:
    symptoms = extract_symptoms(text)
    print(text, symptoms, classify_urgency(text, symptoms))
